# %%
import numpy as np

# %% [markdown]
# ### Using boolean as a lookup and extract indexing method

# %%
# suupose you have a list of companies and a list of their corresponding sectors and you want to find companies within
# specific sectors
# extract companies with sepecific sectors
companies=['A','B','C','D']
accociated_sectors=['Health','Finance','Energy','Finance']

# first of all if you want to use boolean array you have to convert your lists to array
companies_array=np.array(companies)
associated_sectors_array=np.array(accociated_sectors)

# here we define boolean array
boolean_array_Fiancnce_sector=(associated_sectors_array=='Finance')
print(companies_array[boolean_array_Fiancnce_sector])
# Out:
# ['B' 'D']

# %% [markdown]
# ### Visualization basics

# %%
import matplotlib.pyplot as plt
months=np.arange(1,13,1)
prices=[10,14,18,19,15,17,18,21,12,11,15,13]

# plot in a way the x axis is months and y axis is prices (required) but the others like color are optional
plt.plot(months,prices,color='red',linestyle='--')
# always add title
plt.xlabel('months')
plt.ylabel("prices")
plt.title("Average monthly CPI")
plt.show()

# %%
# you can have multiple gtaphs on the same chart by simply adding new plt.plot()
months=np.arange(1,13,1)
prices=[10,14,18,19,15,17,18,21,12,11,15,13]

new_prices=[11,16,12,11,19,16,13,21,10,15,16,18]
# plot in a way the x axis is months and y axis is prices (required) but the others like color are optional
plt.plot(months,prices,color='red',linestyle='-')

#add new graph
plt.plot(months,new_prices,color='blue',linestyle='--')

# always add title
plt.xlabel('months')
plt.ylabel("prices")
plt.title("Average monthly CPI")
plt.show()

# %%
# we can create scatter plots axactly using the same argument as above for plot
months=np.arange(1,13,1)
prices=[10,14,18,19,15,17,18,21,12,11,15,13]

new_prices=[11,16,12,11,19,16,13,21,10,15,16,18]
# plot in a way the x axis is months and y axis is prices (required) but the others like color are optional
plt.scatter(x = months, y = prices,color = 'red', linestyle = '-')

#add new graph
plt.plot(months,new_prices,color='blue',linestyle='-')

# always add title
plt.xlabel('months')
plt.ylabel("prices")
plt.title("Average monthly CPI")
plt.show()

# %% [markdown]
# ### Histograms

# %%
# histograms are exaclty like plots.
prices_1 = [1,2,4,5,9,7,5,5,1,9,5,9,2,5,7,9,1,2,5,4,4,4,6,8,9,6,5]
prices_2 = [10,4,50,40,50,44,66,88,44,11,11,22,44,66,88,99,33,77,77,20]

# Frequency histogram
plt.hist(x = prices_1, bins = 5, label = 'price 1 $')
plt.legend()
plt.show()

# %%
# two histograms together using alpha to make them prnspanrent and visible

prices_1 = [1,2,4,5,9,7,5,5,1,9,5,9,2,5,7,9,1,2,5,4,4,4,6,8,9,6,5]
prices_2 = [10,4,50,40,50,44,66,88,44,11,11,22,44,66,88,99,33,77,77,20]

# Frequency histogram
plt.hist(x = prices_1, bins = 5, density = 1, label = 'price 1 $', alpha = 0.5)
plt.hist(x = prices_2, bins = 5, label = 'price 1 $', alpha = 0.5, density = 1)
plt.legend()
plt.show()

# %%
# lets analyse s&P 100
sp100_companies_name_list =['Apple Inc', 'Abbvie Inc', 'Abbott Laboratories', 'Accenture Plc', 'Allergan Plc', 'American International Group', 'Allstate Corp', 'Amgen', 'Amazon.Com Inc.', 'American Express Company', 'Boeing Company', 'Bank of America Corp', 'Biogen Inc', 'Bank of New York Mellon Corp', 'Blackrock', 'Bristol-Myers Squibb Company', 'Berkshire Hath Hld B', 'Citigroup Inc', 'Caterpillar Inc', 'Celgene Corp', 'Charter Communicatio', 'Colgate-Palmolive Company', 'Comcast Corp A', 'Capital One Financial Corp', 'Conocophillips', 'Costco Wholesale', 'Cisco Systems Inc', 'CVS Corp', 'Chevron Corp', 'Danaher Corp', 'Walt Disney Company', 'Duke Energy Corp', 'Dowdupont Inc.', 'Emerson Electric Company', 'Exelon Corp', 'Ford Motor Company', 'Facebook Inc', 'Fedex Corp', '21st Centry Fox Class B', '21st Centry Fox Class A', 'General Dynamics Corp', 'General Electric Company', 'Gilead Sciences Inc', 'General Motors Company', 'Alphabet Class C', 'Alphabet Class A', 'Goldman Sachs Group', 'Halliburton Company', 'Home Depot', 'Honeywell International Inc', 'International Business Machines', 'Intel Corp', 'Johnson & Johnson', 'JP Morgan Chase & Co', 'Kraft Heinz Co', 'Kinder Morgan', 'Coca-Cola Company', 'Eli Lilly and Company', 'Lockheed Martin Corp', "Lowe's Companies", 'Mastercard Inc', "McDonald's Corp", 'Mondelez Intl Cmn A', 'Medtronic Inc', 'Metlife Inc', '3M Company', 'Altria Group', 'Monsanto Company', 'Merck & Company', 'Morgan Stanley', 'Microsoft Corp', 'Nextera Energy', 'Nike Inc', 'Oracle Corp', 'Occidental Petroleum Corp', 'Priceline Group', 'Pepsico Inc', 'Pfizer Inc', 'Procter & Gamble Company', 'Philip Morris International Inc', 'Paypal Holdings', 'Qualcomm Inc', 'Raytheon Company', 'Starbucks Corp', 'Schlumberger N.V.', 'Southern Company', 'Simon Property Group', 'AT&T Inc', 'Target Corp', 'Time Warner Inc', 'Texas Instruments', 'Unitedhealth Group Inc', 'Union Pacific Corp', 'United Parcel Service', 'U.S. Bancorp', 'United Technologies Corp', 'Visa Inc', 'Verizon Communications Inc', 'Walgreens Boots Alliance', 'Wells Fargo & Company', 'Wal-Mart Stores', 'Exxon Mobil Corp']
sp100_companies_stock_prices_list = [170.12, 93.29, 55.28, 145.3, 171.81, 59.5, 100.5, 168.93, 1126.82, 93.92, 265.04, 26.7, 311.92, 52.73, 474.05, 60.48, 181.27, 71.87, 137.37, 102.88, 346.2, 72.16, 36.13, 88.26, 49.89, 171.22, 36.38, 70.18, 114.84, 93.45, 103.02, 88.61, 71.12, 60.14, 41.32, 12.11, 179.14, 217.75, 30.42, 31.14, 198.7, 17.91, 71.63, 44.74, 1018.48, 1034.09, 238.05, 41.57, 170.13, 148.04, 151.4, 44.88, 138.54, 98.58, 80.59, 17.04, 45.6, 82.97, 312.93, 81.43, 149.93, 167.01, 42.49, 79.52, 51.85, 232.49, 66.51, 118.19, 53.74, 49.06, 82.49, 155.7, 59.46, 48.97, 68.17, 1762.23, 115.5, 35.38, 88.33, 103.35, 76.55, 66.83, 184.22, 56.83, 61.53, 51.12, 159.25, 34.59, 57.77, 88.62, 98.59, 209.75, 115.58, 113.2, 51.88, 117.05, 110.27, 45.85, 70.25, 54.02, 96.08, 80.31]
sp100_companies_EPS_list = [9.2, 5.31, 2.41, 5.91, 15.42, 2.51, 6.79, 12.58, 3.94, 5.22, 9.75, 1.75, 21.59, 3.47, 21.55, 2.96, 6.29, 5.19, 5.55, 6.4, 1.61, 2.87, 2.02, 7.58, 0.02, 5.82, 2.17, 5.71, 3.57, 3.89, 5.7, 4.45, 3.66, 2.58, 2.48, 1.68, 5.19, 11.91, 1.92, 1.92, 10.07, 1.24, 9.58, 6.19, 29.87, 29.87, 19.2, 0.73, 6.96, 6.95, 13.66, 3.18, 7.14, 6.94, 3.56, 0.65, 1.89, 4.09, 12.72, 4.34, 4.31, 6.4, 2.05, 4.69, 5.2, 8.95, 3.16, 5.53, 3.89, 3.61, 3.38, 6.67, 2.35, 2.55, 0.35, 74.45, 5.12, 2.5, 3.98, 4.49, 1.4, 3.78, 7.56, 2.07, 1.29, 2.75, 6.05, 2.93, 4.93, 6.06, 4.06, 9.6, 5.66, 5.98, 3.37, 6.62, 3.48, 3.75, 5.1, 4.14, 4.36, 3.56]


sectors_list = ['Information Technology', 'Health Care', 'Health Care',
       'Information Technology', 'Health Care', 'Financials',
       'Financials', 'Health Care', 'Consumer Discretionary',
       'Financials', 'Industrials', 'Financials', 'Health Care',
       'Financials', 'Financials', 'Health Care', 'Financials',
       'Financials', 'Industrials', 'Health Care',
       'Consumer Discretionary', 'Consumer Staples',
       'Consumer Discretionary', 'Financials', 'Energy',
       'Consumer Staples', 'Information Technology', 'Consumer Staples',
       'Energy', 'Health Care', 'Consumer Discretionary', 'Utilities',
       'Materials', 'Industrials', 'Utilities', 'Consumer Discretionary',
       'Information Technology', 'Industrials', 'Consumer Discretionary',
       'Consumer Discretionary', 'Industrials', 'Industrials',
       'Health Care', 'Consumer Discretionary', 'Information Technology',
       'Information Technology', 'Financials', 'Energy',
       'Consumer Discretionary', 'Industrials', 'Information Technology',
       'Information Technology', 'Health Care', 'Financials',
       'Consumer Staples', 'Energy', 'Consumer Staples', 'Health Care',
       'Industrials', 'Consumer Discretionary', 'Information Technology',
       'Consumer Discretionary', 'Consumer Staples', 'Health Care',
       'Financials', 'Industrials', 'Consumer Staples', 'Materials',
       'Health Care', 'Financials', 'Information Technology', 'Utilities',
       'Consumer Discretionary', 'Information Technology', 'Energy',
       'Consumer Discretionary', 'Consumer Staples', 'Health Care',
       'Consumer Staples', 'Consumer Staples', 'Information Technology',
       'Information Technology', 'Industrials', 'Consumer Discretionary',
       'Energy', 'Utilities', 'Real Estate', 'Telecommunications',
       'Consumer Discretionary', 'Consumer Discretionary',
       'Information Technology', 'Health Care', 'Industrials',
       'Industrials', 'Financials', 'Industrials',
       'Information Technology', 'Telecommunications', 'Consumer Staples',
       'Financials', 'Consumer Staples', 'Energy']



# we want to calculate price to earnings ratio to get the expectation grwoth for this index
# we need to convert these lists to array so that we can caclualte new arrays very quickly rather than using for loop for lists
names = np.array(sp100_companies_name_list)
prices = np.array(sp100_companies_stock_prices_list) 
eps = np.array(sp100_companies_EPS_list)
sectors=np.array(sectors_list)

# now we calculate P/E ratio very quickly
pe = prices / eps
print(pe)
# Out:
# [  18.49130435   17.56873823   22.93775934   24.58544839   11.14202335
#    23.70517928   14.8011782    13.42845787  285.99492386   17.99233716
#    27.18358974   15.25714286   14.44742937   15.19596542   21.99767981
#    20.43243243   28.81875994   13.8477842    24.75135135   16.075
#   215.0310559    25.14285714   17.88613861   11.64379947 2494.5
#    29.41924399   16.76497696   12.29071804   32.16806723   24.02313625
#    18.07368421   19.91235955   19.43169399   23.31007752   16.66129032
#     7.20833333   34.51637765   18.2829555    15.84375      16.21875
#    19.73187686   14.44354839    7.47703549    7.22778675   34.09708738
#    34.6196853    12.3984375    56.94520548   24.44396552   21.30071942
#    11.08345534   14.11320755   19.40336134   14.20461095   22.63764045
#    26.21538462   24.12698413   20.28606357   24.60141509   18.76267281
#    34.78654292   26.0953125    20.72682927   16.95522388    9.97115385
# ...

# %%
# we are interested in information technology and consumer staples so we use boolean arrays to filter it out
# Create boolean array 
boolean_array_IT = (sectors == 'Information Technology')
boolean_array_CS = (sectors == 'Consumer Staples')


# Subset sector-specific data
it_names = names[boolean_array_IT]
it_pe = pe[boolean_array_IT]

cs_names = names[boolean_array_CS]
cs_pe = pe[boolean_array_CS]

# Display sector names
print(it_names,"\n")
print(it_pe,"\n", "--------------------------------------------------------------------------------------")

print(cs_names,"\n")
print(cs_pe)
# Out:
# ['Apple Inc' 'Accenture Plc' 'Cisco Systems Inc' 'Facebook Inc'
#  'Alphabet Class C' 'Alphabet Class A' 'International Business Machines'
#  'Intel Corp' 'Mastercard Inc' 'Microsoft Corp' 'Oracle Corp'
#  'Paypal Holdings' 'Qualcomm Inc' 'Texas Instruments' 'Visa Inc']
#
# [18.49130435 24.58544839 16.76497696 34.51637765 34.09708738 34.6196853
#  11.08345534 14.11320755 34.78654292 24.40532544 19.20392157 54.67857143
#  17.67989418 24.28325123 31.68678161]
#  --------------------------------------------------------------------------------------
# ['Colgate-Palmolive Company' 'Costco Wholesale' 'CVS Corp'
#  'Kraft Heinz Co' 'Coca-Cola Company' 'Mondelez Intl Cmn A' 'Altria Group'
#  'Pepsico Inc' 'Procter & Gamble Company'
#  'Philip Morris International Inc' 'Walgreens Boots Alliance'
#  'Wal-Mart Stores']
#
# [25.14285714 29.41924399 12.29071804 22.63764045 24.12698413 20.72682927
#  21.04746835 22.55859375 22.19346734 23.01781737 13.7745098  22.03669725]

# %%
# calculating mean and standard deviation of the constitutes in IT sector in S&P 100
it_pe_mean = np.mean(it_pe)
it_pe_std = np.std(it_pe)

print(it_pe_mean)
print(it_pe_std)
# Out:
# 26.333055420408595
# 10.8661467926753

# %%
# assign ID to each compay name be cause they get messy if we use names on x axis

# Make a scatterplot
plt.scatter(it_names, it_pe, color='red', label='IT')
plt.scatter(cs_names, cs_pe, color = 'green', label='CS')

# Add legend
plt.legend()

# Add labels
plt.xlabel('Company ID')
plt.ylabel('P/E Ratio')
plt.show()

# %%
# Identify P/E ratio within it_pe that is > 50
outlier_price = it_pe[it_pe>34]
# Identify the company with PE ratio > 50
outlier_name = it_names[it_pe>34]

# Display results
print("In 2017, " + str(outlier_name[0]) + " had an abnormally high P/E ratio of " + str(round(outlier_price[0], 2)) + ".")
# Out:
# In 2017, Facebook Inc had an abnormally high P/E ratio of 34.52.

# %%
outlier_name
# Out:
# array(['Facebook Inc', 'Alphabet Class C', 'Alphabet Class A',
#        'Mastercard Inc', 'Paypal Holdings'], dtype='<U31')

# %%
outlier_price
# Out:
# array([34.51637765, 34.09708738, 34.6196853 , 34.78654292, 54.67857143])

# %% [markdown]
# ### Using boolean array for filtering data

# %%
name = ['a','b','c','d','e']
salary = [2,4,6,8,1]

# %%
# 2 stage meathod: using boolean array for filtering data 
# first we need to convert lists to array to be able to use filtering method without using for loop
name_array=np.array(name)
salary_array=np.array(salary)
boolean_array_salary_above_5 = (salary_array>5)

print(boolean_array_salary_above_5)
print(name_array[boolean_array_salary_above_5])
print(salary_array[boolean_array_salary_above_5])
# Out:
# [False False  True  True False]
# ['c' 'd']
# [6 8]

# %%
# 1 stage method, instead of using boolean array we use the conditon directly
# as you see the condition is equivalent to boolean array
[salary_array>5]
# Out:
# [array([False, False,  True,  True, False])]

# %%
print(name_array[salary_array>5])
print(salary_array[salary_array>5])
# Out:
# ['c' 'd']
# [6 8]

# %% [markdown]
# ### Datetime

# %%
from datetime import datetime
# the below function gives the current time
datetime.now()
# Out:
# datetime.datetime(2021, 6, 26, 17, 15, 1, 402842)

# %%
# sometimes we have data and time in form of a string and we need to convert it to datetime to be able to analys it
black_monday_str="Monday, October 19, 1987. 9:30 am"
# we have the above str, lets define its format first
format_str = "%A, %B %d, %Y. %I:%M %p"
# now we use the two above inputs for strptime functiondt.
datetime.strptime(black_monday_str,format_str)
# Out:
# datetime.datetime(1987, 10, 19, 9, 30)

# %%
date_1 = '1837-05-10'
format_str = "%Y-%m-%d"
datetime.strptime(date_1,format_str)
# Out:
# datetime.datetime(1837, 5, 10, 0, 0)

# %%
# we can do the reverse which is very useful in reporting
# using strftime function
datetime_1 = datetime(1837, 5, 10)
datetime_1
# Out:
# datetime.datetime(1837, 5, 10, 0, 0)

# %%
# now we convert it to string
data_1_str = datetime_1.strftime("%A, ;-) %b %d, %Y")
data_1_str
# Out:
# 'Wednesday, ;-) May 10, 1837'

# %%
# by combining both strptime and strftime we can convert from one format to another
date_1 ='1837-05-10'
format1_str = "%Y-%m-%d"
date_1_datetime = datetime.strptime(date_1,format1_str)

# %%
date_1_datetime.strftime("%A- %B %dth, %Y")
# Out:
# 'Wednesday- May 10th, 1837'

# %%
# we can easily extract data from datetime and store them in variables
date_1_hours = date_1_datetime.year
print(date_1_hours )

print(date_1_datetime.month)
print(date_1_datetime.day)
# Out:
# 1837
# 5
# 10

# %%
# datetime.now() is also an object name. we can use like date_1_datetime above
datetime.now().hour
# Out:
# 17

# %%
# using operator like > < == in datetime
datetime_1 = datetime(1837, 5, 10)
datetime_2 = datetime(2000, 4, 10)
datetime_1 == datetime_2
# Out:
# False

# %%
datetime_1 < datetime_2
# Out:
# True

# %%
# by subtracting to datetimes we get how long between these to dates which creates a new object called timedelta
timedelta_date1_date2 = datetime_2 - datetime_1
type(timedelta_date1_date2)
# Out:
# datetime.timedelta

# %%
# return number of hours between these two dates
timedelta_date1_date2.days
# Out:
# 59505

# %%
# creating new datetime from the existing one, 
# lets see one week before datetime_1
datetime_new = datetime(datetime_1.year + 2, datetime_1.month + 7, datetime_1.day - 5)
datetime_new
# Out:
# datetime.datetime(1839, 12, 5, 0, 0)

# %%
# the above method is not recommended and is inefficient, it's better to use our own timedelta
# first we should add relevant module

from datetime import timedelta

datetime_1 = datetime(1837, 5, 10)

one_week_timedelta = timedelta(weeks = 1)
one_week_before_date_1 = date_1_datetime - one_week_timedelta

one_week_before_date_1
# Out:
# datetime.datetime(1837, 5, 3, 0, 0)

# %%
# instead of week we can use days, hours, ...
datetime_1 = datetime(1837, 5, 10)

one_week_timedelta = timedelta(days = 159)
one_week_before_date_1 = date_1_datetime - one_week_timedelta

one_week_before_date_1
# Out:
# datetime.datetime(1836, 12, 2, 0, 0)

# %%
# puting a boolean variable (true or false) in a print output
GFC_datetime = (2008, 9, 15)
Covid_pandemic_datetime = (2020,1,1)

GFC_datetime_first = (GFC_datetime < Covid_pandemic_datetime)

# we put an f before " " and put the boolean variable in a {}
print(f"it is {GFC_datetime_first} that Great Financial Crisis happened before covid")
# Out:
# it is True that Great Financial Crisis happened before covid

# %%
print('Sasan'==5)
# Out:
# False

# %% [markdown]
# ### filtering and masking DataFrames

# %%
import pandas as pd

# %%
Nasdaq = pd.read_csv("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\Nasdaq.csv")
Nasdaq.head()
# Out:
#          Date          Open          High          Low         Close  \
# 0  2020-06-16   9949.780273   9963.629883  9748.379883   9895.870117
# 1  2020-06-17   9943.309570   9991.209961  9891.809570   9910.530273
# 2  2020-06-18   9892.480469   9959.200195  9885.660156   9943.049805
# 3  2020-06-19  10042.129883  10053.910156  9872.940430   9946.120117
# 4  2020-06-22   9945.490234  10059.610352  9916.599609  10056.480469
#
#       Adj Close      Volume
# 0   9895.870117  4639860000
# 1   9910.530273  4249680000
# 2   9943.049805  4294740000
# 3   9946.120117  6068130000
# 4  10056.480469  4468000000

# %%
# similar to head we can see the last rows using tail
Nasdaq.tail(2)
# Out:
#            Date          Open          High           Low         Close  \
# 251  2021-06-15  14166.639648  14171.019531  14052.160156  14072.860352
# 252  2021-06-16  14085.599609  14128.164063  14079.711914  14124.078125
#
#         Adj Close      Volume
# 251  14072.860352  4517770000
# 252  14124.078125   934839516

# %%
#FILTERIG
# first creast a boolean condition
# Create a mask for all of the rows whose daily high is greater than $14000.
greater_than_14000_condition = Nasdaq.High > 14000
greater_than_14000_condition
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 248     True
# 249     True
# 250     True
# 251     True
# 252     True
# Name: High, Length: 253, dtype: bool

# %%
# create a new DataFrame from above (Filtering) using loc and condition

Nasdaq_filtered_14000high = Nasdaq.loc[greater_than_14000_condition]
Nasdaq_filtered_14000high
# Out:
#            Date          Open          High           Low         Close  \
# 164  2021-02-09  13966.820313  14044.950195  13966.549805  14007.700195
# 165  2021-02-10  14093.349609  14109.120117  13845.469727  13972.530273
# 166  2021-02-11  14045.209961  14058.910156  13916.849609  14025.769531
# 167  2021-02-12  13979.209961  14102.040039  13937.709961  14095.469727
# 168  2021-02-16  14152.209961  14175.120117  13995.450195  14047.500000
# 207  2021-04-13  13902.450195  14011.509766  13902.450195  13996.099609
# 208  2021-04-14  14004.080078  14033.629883  13839.040039  13857.839844
# 209  2021-04-15  13983.230469  14049.129883  13970.419922  14038.759766
# 210  2021-04-16  14059.110352  14062.500000  13977.049805  14052.339844
# 211  2021-04-19  13984.580078  14041.790039  13842.570313  13914.769531
# 214  2021-04-22  13952.570313  14015.870117  13771.040039  13818.410156
# 215  2021-04-23  13861.370117  14062.740234  13856.830078  14016.809570
# ...

# %%
# we can find specific numbers using the above method
Nasdaq_volume_condition = Nasdaq.Volume == 4468000000
Nasdaq_filtered_volume = Nasdaq.loc[Nasdaq_volume_condition]
Nasdaq_filtered_volume
# Out:
#          Date         Open          High          Low         Close  \
# 4  2020-06-22  9945.490234  10059.610352  9916.599609  10056.480469
#
#       Adj Close      Volume
# 4  10056.480469  4468000000

# %%
# we can combine more than one condition to get our desired results
# first make sure we have our dates in date format
Nasdaq['Date'] = pd.to_datetime(Nasdaq['Date'])
# then set the start and end date
start_date = datetime(2021, 5, 1)
end_date = datetime(2021, 5, 30)
Nasdaq_date_condition = (Nasdaq['Date'] >= start_date) & (Nasdaq['Date'] <= end_date)

# %%
# we can skip loc and just use the condition
Nasdaq_filtered_date = Nasdaq[Nasdaq_date_condition]
Nasdaq_filtered_date.head()
# Out:
#           Date          Open          High           Low         Close  \
# 221 2021-05-03  14031.769531  14042.120117  13881.509766  13895.120117
# 222 2021-05-04  13774.509766  13795.570313  13485.589844  13633.500000
# 223 2021-05-05  13731.129883  13753.049805  13553.929688  13582.419922
# 224 2021-05-06  13557.830078  13635.730469  13439.389648  13632.839844
# 225 2021-05-07  13723.089844  13828.620117  13690.750000  13752.240234
#
#         Adj Close      Volume
# 221  13895.120117  4718850000
# 222  13633.500000  5852850000
# 223  13582.419922  4517100000
# 224  13632.839844  5000710000
# 225  13752.240234  4376800000

# %%
Nasdaq_filtered_date = Nasdaq.loc[Nasdaq_date_condition]
Nasdaq_filtered_date.tail()
# Out:
#           Date          Open          High           Low         Close  \
# 236 2021-05-24  13557.209961  13708.849609  13551.009766  13661.169922
# 237 2021-05-25  13721.540039  13751.139648  13631.799805  13657.169922
# 238 2021-05-26  13693.940430  13750.160156  13679.589844  13738.000000
# 239 2021-05-27  13742.589844  13776.519531  13701.629883  13736.280273
# 240 2021-05-28  13792.049805  13820.870117  13747.610352  13748.740234
#
#         Adj Close      Volume
# 236  13661.169922  3490650000
# 237  13657.169922  4084480000
# 238  13738.000000  4231140000
# 239  13736.280273  5057550000
# 240  13748.740234  4435220000

# %%
# plotting DataFrames
Nasdaq.plot(x = 'Date', y = 'Adj Close')

# %%
# we can rotate the x axis label on the plot by degrees to make it easier to read, and we can add title as well
Nasdaq.plot(x = 'Date', y = 'Adj Close', rot = 90, title = 'NASDAQ price')

# %%
# we can set one of our columns as index
Nasdaq_with_Date_as_index = Nasdaq.set_index('Date', inplace= False)
# so our x would be our index by default
Nasdaq_with_Date_as_index.plot(y = 'Adj Close')

# %%
# the defualt plot is line, but there is other kind of plots as well: kind = 'bar' or 'hist' or 'pie' , ...
Nasdaq.plot(x = 'Date', y = 'Adj Close', kind = 'bar')

# %%
# as you see it is so messy, lets make bar by month, first we need to add another column : month
#Nasdaq['month'] = pd.DatetimeIndex(Nasdaq['Date']).month
Nasdaq['month_year'] = pd.to_datetime(Nasdaq['Date']).dt.to_period('M')
Nasdaq.head(2)
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0 2020-06-16  9949.780273  9963.629883  9748.379883  9895.870117  9895.870117
# 1 2020-06-17  9943.309570  9991.209961  9891.809570  9910.530273  9910.530273
#
#        Volume month_year
# 0  4639860000    2020-06
# 1  4249680000    2020-06

# %%
# as you see it is messy, it is better to extract monthly data from the beginning instead of daily 
Nasdaq.plot(x = 'month_year', y = 'Adj Close', kind = 'bar')

# %% [markdown]
# ### Time Value of Money, Present Value and Future Value in Python

# %%
import numpy as np
# present value formula
rate = 0.01
nper = 30
pmt = 0
fv = 100
np.pv(rate = rate, nper = nper, pmt = pmt, fv = fv)
# Out:
# C:\Users\sasan\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: numpy.pv is deprecated and will be removed from NumPy 1.20. Use numpy_financial.pv instead (https://pypi.org/project/numpy-financial/).
#   import sys
# -74.1922917787124

# %%
# future value formula

np.fv(rate = 0.01, nper = 30, pmt = 0, pv = -74.1923)
# Out:
# C:\Users\sasan\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: numpy.fv is deprecated and will be removed from NumPy 1.20. Use numpy_financial.fv instead (https://pypi.org/project/numpy-financial/).
#   This is separate from the ipykernel package so we can avoid doing imports until
# 100.00001108105357

# %%
# NPV - Net Present Value
cashflow_array = np.array([-100, 20, 30, 40, 50, 50, 100])
np.npv(rate = 0.10, values = cashflow_array)
# Out:
# C:\Users\sasan\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: numpy.npv is deprecated and will be removed from NumPy 1.20. Use numpy_financial.npv instead (https://pypi.org/project/numpy-financial/).
#   This is separate from the ipykernel package so we can avoid doing imports until
# 94.67193057422234

# %%
# IRR - internal rate of return
cashflow_array = np.array([-100, 20, 30, 40, 50, 50, 100])
np.irr(values = cashflow_array)
# Out:
# C:\Users\sasan\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: numpy.irr is deprecated and will be removed from NumPy 1.20. Use numpy_financial.irr instead (https://pypi.org/project/numpy-financial/).
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0.3109848652527907

# %%
# EAA : Equivalent Annual Annuity (pmt)
cashflow_array = np.array([-100, 20, 30, 40, 50, 50, 100])
npv = np.npv(rate = 0.10, values = cashflow_array)
np.pmt(rate = 0.10, nper = 30, pv = -1*npv, fv = 0 )
# Out:
# C:\Users\sasan\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: numpy.npv is deprecated and will be removed from NumPy 1.20. Use numpy_financial.npv instead (https://pypi.org/project/numpy-financial/).
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\sasan\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: numpy.pmt is deprecated and will be removed from NumPy 1.20. Use numpy_financial.pmt instead (https://pypi.org/project/numpy-financial/).
#   after removing the cwd from sys.path.
# 10.042727225939053

# %% [markdown]
# ### Morgtgage amortization

# %%
import numpy as np

# Set the value of the home you are looking to buy
home_value = 800000

# What percentage are you paying up-front?
down_payment_percent = 0.2

# Calculate the dollar value of the down payment
down_payment = 0.2*home_value
print("Initial Down Payment: " + str(down_payment))

# Calculate the value of the mortgage loan required after the down payment
mortgage_loan = home_value-down_payment
print("Mortgage Loan: " + str(mortgage_loan))
# Out:
# Initial Down Payment: 160000.0
# Mortgage Loan: 640000.0

# %%
# we need to calculate qouted annual rate to monthly rate
quoted_annual_rate = 0.12
payment_period_in_year = 12

mortgage_rate_periodic = (1+quoted_annual_rate)**(1/payment_period_in_year)-1
mortgage_rate_periodic
# Out:
# 0.009488792934583046

# %%
# then we need to calculate period payment in dollar
loan_term_year = 30
mortgage_payment_periods = loan_term_year * payment_period_in_year


periodic_mortgage_payment = -np.pmt(rate = mortgage_rate_periodic, nper = mortgage_payment_periods, 
                                    pv = mortgage_loan, fv = 0)
periodic_mortgage_payment
# Out:
# C:\Users\sasan\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: numpy.pmt is deprecated and will be removed from NumPy 1.20. Use numpy_financial.pmt instead (https://pypi.org/project/numpy-financial/).
#   import sys
# 6282.525123478265

# %%
# Calculate the amount of the first loan payment that will go towards interest
initial_interest_payment = mortgage_loan * mortgage_rate_periodic
print("Initial Interest Payment: " + str(round(initial_interest_payment, 2)))

# Calculate the amount of the first loan payment that will go towards principal
initial_principal_payment = periodic_mortgage_payment-initial_interest_payment
print("Initial Principal Payment: " + str(round(initial_principal_payment, 2)))
# Out:
# Initial Interest Payment: 6072.83
# Initial Principal Payment: 209.7

# %%
# defining an empty array
principal_remaining = np.zeros(30*12)
# Loop through each mortgage payment period
for i in range(0, mortgage_payment_periods):
    
    # Handle the case for the first iteration
    if i == 0:
        previous_principal_remaining = mortgage_loan
    else:
        previous_principal_remaining = principal_remaining[i-1]
        
    # Calculate the interest and principal payments
    interest_payment = round(previous_principal_remaining * mortgage_rate_periodic, 2)
    principal_payment = round(periodic_mortgage_payment - interest_payment, 2)
    
    # Catch the case where all principal is paid off in the final period
    if previous_principal_remaining - principal_payment < 0:
        principal_payment = previous_principal_remaining
        
    # Collect the principal remaining values in an array
    principal_remaining[i] = previous_principal_remaining - principal_payment
    
    # Print the payments for the first few periods
print(principal_remaining)  # need modification
# Out:
# [639790.3  639578.61 639364.91 639149.18 638931.4  638711.56 638489.63
#  638265.6  638039.44 637811.13 637580.66 637348.   637113.13 636876.03
#  636636.68 636395.06 636151.15 635904.93 635656.37 635405.45 635152.15
#  634896.45 634638.32 634377.74 634114.69 633849.14 633581.07 633310.46
#  633037.28 632761.51 632483.12 632202.09 631918.39 631632.   631342.9
#  631051.05 630756.43 630459.02 630158.79 629855.71 629549.75 629240.89
#  628929.1  628614.35 628296.61 627975.86 627652.06 627325.19 626995.22
#  626662.12 626325.86 625986.41 625643.74 625297.81 624948.6  624596.08
#  624240.21 623880.97 623518.32 623152.23 622782.66 622409.59 622032.98
#  621652.79 621268.99 620881.55 620490.44 620095.62 619697.05 619294.7
#  618888.53 618478.51 618064.59 617646.75 617224.94 616799.13 616369.28
#  615935.35 615497.3  615055.1  614608.7  614158.06 613703.15 613243.92
#  612780.33 612312.35 611839.93 611363.02 610881.59 610395.59 609904.98
# ...

# %%
# Loop through each mortgage payment period
interest_paid = np.zeros(30*12)
principal_paid = np.zeros(30*12)
principal_remaining = np.zeros(30*12)

for i in range(0, mortgage_payment_periods):
    
    # Handle the case for the first iteration
    if i == 0:
        previous_principal_remaining = mortgage_loan
    else:
        previous_principal_remaining = principal_remaining[i-1]
        
    # Calculate the interest based on the previous principal
    interest_payment = round(previous_principal_remaining*mortgage_rate_periodic, 2)
    principal_payment = round(periodic_mortgage_payment - interest_payment, 2)
    
    # Catch the case where all principal is paid off in the final period
    if previous_principal_remaining - principal_payment < 0:
        principal_payment = previous_principal_remaining
        
    # Collect the historical values
    interest_paid[i] = interest_payment
    principal_paid[i] = principal_payment
    principal_remaining[i] = previous_principal_remaining - principal_payment
    
# Plot the interest vs principal
plt.plot(interest_paid, color="red")
plt.plot(principal_paid, color="blue")
plt.show()

# %%
# calculating cumulatives without using for loop
# Calculate the cumulative home equity (principal) over time
cumulative_home_equity = np.cumsum(principal_paid)

# Calculate the cumulative interest paid over time
cumulative_interest_paid = np.cumsum(interest_paid)

# Calculate your percentage home equity over time
cumulative_percent_owned = down_payment_percent + (cumulative_home_equity/home_value)
print(cumulative_percent_owned)

# Plot the cumulative interest paid vs equity accumulated
plt.plot(cumulative_interest_paid, color='red')
plt.plot(cumulative_home_equity, color='blue')
plt.show()
# Out:
# [0.20026213 0.20052674 0.20079386 0.20106353 0.20133575 0.20161055
#  0.20188796 0.202168   0.2024507  0.20273609 0.20302418 0.203315
#  0.20360859 0.20390496 0.20420415 0.20450618 0.20481106 0.20511884
#  0.20542954 0.20574319 0.20605981 0.20637944 0.2067021  0.20702782
#  0.20735664 0.20768858 0.20802366 0.20836193 0.2087034  0.20904811
#  0.2093961  0.20974739 0.21010201 0.21046    0.21082138 0.21118619
#  0.21155446 0.21192623 0.21230151 0.21268036 0.21306281 0.21344889
#  0.21383863 0.21423206 0.21462924 0.21503018 0.21543492 0.21584351
#  0.21625598 0.21667235 0.21709268 0.21751699 0.21794533 0.21837774
#  0.21881425 0.2192549  0.21969974 0.22014879 0.2206021  0.22105971
#  0.22152168 0.22198801 0.22245878 0.22293401 0.22341376 0.22389806
#  0.22438695 0.22488048 0.22537869 0.22588163 0.22638934 0.22690186
#  0.22741926 0.22794156 0.22846883 0.22900109 0.2295384  0.23008081
#  0.23062837 0.23118113 0.23173913 0.23230243 0.23287106 0.2334451
# ...

# %%
# assume home value in the market increases by 0.25% every month
growth_list = [0.0025]*30*12
growth_array = np.array(growth_list)

# Calculate the cumulative growth over time
cumulative_growth_forecast = np.cumprod( 1 + growth_array)

# Forecast the home value over time
home_value_forecast = home_value * cumulative_growth_forecast

# Forecast the home equity value owned over time
cumulative_home_value_owned = home_value_forecast * cumulative_percent_owned

# Plot the home value vs equity accumulated
plt.plot(home_value_forecast, color='red')
plt.plot(cumulative_home_value_owned, color='blue')
plt.show()

# %%
# Underwater mortgage when the remaining mortgage is higher than the home value
import numpy as np
import pandas as pd

# assume home value in the market decrease by 0.45% every month
decline_list = [-0.0045]*30*12
decline_array = np.array(decline_list)

# Cumulative drop in home value over time as a ratio
cumulative_decline_forecast = np.cumprod(1+decline_array)

# Forecast the home value over time
home_value_forecast = home_value * cumulative_decline_forecast

# Find all periods where your mortgage is underwater
underwater = (home_value_forecast < principal_remaining) 
pd.value_counts(underwater)

# Plot the home value vs principal remaining
plt.plot(home_value_forecast, color='red')
plt.plot(principal_remaining, color='blue')
plt.show()

# %% [markdown]
# ### Budgetting

# %%
# Enter your annual salary
salary = 85000

# Assume a tax rate of 30%
tax_rate = 0.3

# Calculate your salary after taxes
salary_after_taxes = salary * (1 - tax_rate)
print("Salary after taxes: " + str(round(salary_after_taxes, 2)))

# Calculate your monthly salary after taxes
monthly_takehome_salary = salary_after_taxes / 12
print("Monthly takehome salary: " + str(round(monthly_takehome_salary, 2)))
# Out:
# Salary after taxes: 59500.0
# Monthly takehome salary: 4958.33

# %%
# Enter your monthly rent
monthly_rent = 1200

# Enter your daily food budget
daily_food_budget = 30

# Calculate your monthly food budget assuming 30 days per month
monthly_food_budget = daily_food_budget * 30

# Set your monthly entertainment budget
monthly_entertainment_budget = 200

# Allocate funds for unforeseen expenses, just in case
monthly_unforeseen_expenses = 250

# Next, calculate your total monthly expenses
monthly_expenses = monthly_rent + monthly_food_budget + monthly_entertainment_budget + monthly_unforeseen_expenses

print("Monthly expenses: " + str(round(monthly_expenses, 2)))

# Finally, calculate your monthly take-home savings
monthly_savings = monthly_takehome_salary - monthly_expenses
print("Monthly savings: " + str(round(monthly_savings, 2)))
# Out:
# Monthly expenses: 2550
# Monthly savings: 2408.33

# %%
# side info:
# repeat function is very useful in forecasting or creating arrays and you can set consecutive rate and numbers
print('np.repeat(0.05,3)----------------------->' + str(np.repeat(0.05,3)))
print('np.repeat([0.05, 0.10, 0.7], [1, 2, 3]-->' + str(np.repeat([0.05, 0.10, 0.07], [1, 2, 3])))
# Out:
# np.repeat(0.05,3)----------------------->[0.05 0.05 0.05]
# np.repeat([0.05, 0.10, 0.7], [1, 2, 3]-->[0.05 0.1  0.1  0.07 0.07 0.07]

# %%
# and you can use the above to calcuate amonunt based on those growth rate
dollar_value_each_year_100USD = 100 * np.cumprod(1 + np.repeat([0.05, 0.10, 0.07], [1, 2, 3]))
dollar_value_each_year_100USD
# it shows the accumulated dollar of your $100 initial investment
# Out:
# array([105.        , 115.5       , 127.05      , 135.9435    ,
#        145.459545  , 155.64171315])

# %%
# lets get back to our budgeting three cells above

# Create monthly forecasts up to 15 years from now
forecast_months = 12*15

# Set your annual salary growth rate
annual_salary_growth = 0.05

# Calculate your equivalent monthly salary growth rate
monthly_salary_growth = (1 + annual_salary_growth) ** (1/12) - 1

# Forecast the cumulative growth of your salary
cumulative_salary_growth_forecast = np.cumprod(np.repeat(1 + monthly_salary_growth, forecast_months))

# Calculate the actual salary forecast
salary_forecast = monthly_takehome_salary * cumulative_salary_growth_forecast

# Plot the forecasted salary
plt.plot(salary_forecast, color='blue')
plt.show()

# %%
# we do the same thing to project expenses
# Set the annual inflation rate
annual_inflation = 0.025

# Calculate the equivalent monthly inflation rate
monthly_inflation = (1 + annual_inflation) ** (1/12) - 1

# Forecast cumulative inflation over time
cumulative_inflation_forecast = np.cumprod ( 1 + np.repeat(monthly_inflation, forecast_months))

# Calculate your forecasted expenses
expenses_forecast = monthly_expenses * cumulative_inflation_forecast

# Plot the forecasted expenses
plt.plot(expenses_forecast, color='red')
plt.show()

# %%
# Calculate your savings for each month
savings_forecast = salary_forecast - expenses_forecast

# Calculate your cumulative savings over time
cumulative_savings = np.cumsum(savings_forecast)

# Print the final cumulative savings after 15 years
final_net_worth = cumulative_savings[-1]
print("Your final net worth: " + str(round(final_net_worth, 2)))

# Plot the forecasted savings
plt.plot(cumulative_savings, color='blue')
plt.show()
# Out:
# Your final net worth: 762318.83

# %%
# Set the annual investment return to 7%
investment_rate_annual = 0.07

# Calculate the monthly investment return
investment_rate_monthly = (1 + investment_rate_annual) ** (1/12) - 1

# Calculate your required monthly investment to amass $1M
required_investment_monthly = -1 * np.pmt(rate=investment_rate_monthly, nper=forecast_months, pv=0, fv=1000000)
print("You will have to invest $" + str(round(required_investment_monthly, 2)) + " per month to amass $1M over 15 years")
# Out:
# You will have to invest $3214.35 per month to amass $1M over 15 years
# C:\Users\sasan\anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: numpy.pmt is deprecated and will be removed from NumPy 1.20. Use numpy_financial.pmt instead (https://pypi.org/project/numpy-financial/).

# %%
# assume
monthly_investment_percentage = 0.3

# calulate take home cashflow forecat
cash_flow_forecast = salary_forecast - expenses_forecast

# Calculate your monthly deposit into your investment account
investment_deposit_forecast = monthly_investment_percentage * cash_flow_forecast

# The rest goes into your savings account
savings_forecast_new = cash_flow_forecast - investment_deposit_forecast

# Calculate your cumulative savings over time
cumulative_savings_new = np.cumsum(savings_forecast_new)

# Plot your forecasted monthly savings vs investments
plt.plot(investment_deposit_forecast, color='red')
plt.plot(savings_forecast_new, color='blue')
## plt.legend(handles=[investments_plot, savings_plot], loc=2)
plt.show()

# %%
# create initial array with size forecast_months to be populated later
net_worth = np.array([0] * forecast_months)
investment_portfolio = np.array([0] * forecast_months)

# Loop through each forecast period
for i in range(forecast_months):
    
    # Find the previous investment deposit amount
    if i == 0: 
        previous_investment = 0
    else:
        previous_investment = investment_portfolio[i-1]
        
    # Calculate the value of your previous investments, which have grown
    previous_investment_growth = previous_investment*(1 + investment_rate_monthly)
    
    # Add your new deposit to your investment portfolio
    investment_portfolio[i] =  previous_investment_growth + investment_deposit_forecast[i]
    
    # Calculate your net worth at each point in time
    net_worth[i] = investment_portfolio[i] + cumulative_savings_new[i]
         
# Plot your forecasted cumulative savings vs investments and net worth
### need to check :  
# plot_investments(investment_portfolio, cumulative_savings_new, net_worth)
net_worth
# Out:
# array([  2422,   4864,   7325,   9806,  12306,  14825,  17364,  19923,
#         22502,  25102,  27721,  30361,  33022,  35703,  38405,  41127,
#         43871,  46636,  49423,  52230,  55060,  57911,  60783,  63678,
#         66595,  69533,  72495,  75478,  78485,  81514,  84567,  87641,
#         90740,  93862,  97007, 100176, 103369, 106586, 109827, 113091,
#        116381, 119695, 123034, 126397, 129786, 133199, 136638, 140102,
#        143592, 147108, 150650, 154217, 157811, 161431, 165078, 168752,
#        172453, 176181, 179936, 183718, 187528, 191366, 195232, 199126,
#        203049, 206999, 210979, 214987, 219025, 223091, 227186, 231312,
#        235466, 239651, 243865, 248111, 252386, 256692, 261030, 265398,
#        269796, 274228, 278690, 283184, 287711, 292269, 296860, 301483,
#        306140, 310829, 315551, 320306, 325096, 329918, 334775, 339666,
#        344592, 349552, 354546, 359577, 364642, 369742, 374879, 380052,
# ...

# %%
# final step : ADJUSTING FOR INFLATION
import numpy as np

# Set your future net worth
future_net_worth = 900000

# Set the annual inflation rate to 2.5%
annual_inflation = 0.025

# Calculate the present value of your terminal wealth over 15 years
inflation_adjusted_net_worth = np.pv(rate=annual_inflation, nper=15, pmt=0, fv=-1*future_net_worth)
print("Your inflation-adjusted net worth: $" + str(round(inflation_adjusted_net_worth, 2)))
# Out:
# Your inflation-adjusted net worth: $621419.0
# C:\Users\sasan\anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: numpy.pv is deprecated and will be removed from NumPy 1.20. Use numpy_financial.pv instead (https://pypi.org/project/numpy-financial/).
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ### Time Series

# %%
# for working with times series we need the following library and module
import pandas as pd 
from datetime import datetime

# Timestamp in very usful object, we should convert times in form of datetime or string to timedtamp
time_stamp_1 = pd.Timestamp(datetime(1985, 7, 10)) # becareful: Timestamp with Capital T
time_stamp_1
# Out:
# Timestamp('1985-07-10 00:00:00')

# %%
# string for Timestamp
time_stamp_1 = pd.Timestamp('1985-7-10') # becareful: Timestamp with Capital T
time_stamp_1
# Out:
# Timestamp('1985-07-10 00:00:00')

# %%
# we can access variuos time asepcts of our data
time_stamp_1.year
# Out:
# 1985

# %%
time_stamp_1.day_name()
# Out:
# 'Wednesday'

# %%
# Create the range of dates here
seven_days = pd.date_range(start = '2017-1-1', periods = 7, freq = 'D') # instead of periods we can use end= 

seven_days
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
print(seven_days[0].dayofweek)
print(seven_days[0].day_name())
# Out:
# 6
# Sunday

# %%
# Iterate over the dates and print the number and name of the weekday
for day in seven_days:
    print(str(day.dayofweek) + " " + str(day.day_name()))
# Out:
# 6 Sunday
# 0 Monday
# 1 Tuesday
# 2 Wednesday
# 3 Thursday
# 4 Friday
# 5 Saturday

# %%
# timetamps vs periods : timestamps are point in time whereas Periods is a period of time
period_of_time = pd.Period('2017-05', freq = 'M')
period_of_time
# Out:
# Period('2017-05', 'M')

# %%
period_of_time.month
# Out:
# 5

# %%
period_of_time.day
# Out:
# 31

# %%
# we can change freq of period by asfreq
period_of_time.asfreq('D')
period_of_time
# Out:
# Period('2017-05', 'M')

# %%
# we can convert period to timestamp and vice versa
period_of_time.to_timestamp()
# Out:
# Timestamp('2017-05-01 00:00:00')

# %%
time_stamp_1.to_period(freq = 'M')
# Out:
# Period('1985-07', 'M')

# %%
# Frequency info enables basic date arithmetic
period_of_time + 1
# Out:
# Period('2017-06', 'M')

# %%
data = pd.read_csv("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\Nasdaq.csv")
data.head()
# Out:
#          Date          Open          High          Low         Close  \
# 0  2020-06-16   9949.780273   9963.629883  9748.379883   9895.870117
# 1  2020-06-17   9943.309570   9991.209961  9891.809570   9910.530273
# 2  2020-06-18   9892.480469   9959.200195  9885.660156   9943.049805
# 3  2020-06-19  10042.129883  10053.910156  9872.940430   9946.120117
# 4  2020-06-22   9945.490234  10059.610352  9916.599609  10056.480469
#
#       Adj Close      Volume
# 0   9895.870117  4639860000
# 1   9910.530273  4249680000
# 2   9943.049805  4294740000
# 3   9946.120117  6068130000
# 4  10056.480469  4468000000

# %%
# Using info() we can see the columns title and their data type
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       253 non-null    object
#  1   Open       253 non-null    float64
#  2   High       253 non-null    float64
#  3   Low        253 non-null    float64
#  4   Close      253 non-null    float64
#  5   Adj Close  253 non-null    float64
#  6   Volume     253 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 14.0+ KB

# %%
# always when we start working with dateframes and want to do time sries, we need to first change the date column from
# object or string to datetime to be able to work easier with. and then set that date column as index

# Convert the date column to datetime64
data.Date = pd.to_datetime(data.Date)

# Set date column as index --> this change the dataframe to a time series dataframe calle datetimeindex
data_date_time_index = data.set_index('Date')

# Inspect data 
print(data_date_time_index.info())

# Plot data
data_date_time_index.plot(subplots=True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 253 entries, 2020-06-16 to 2021-06-16
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       253 non-null    float64
#  1   High       253 non-null    float64
#  2   Low        253 non-null    float64
#  3   Close      253 non-null    float64
#  4   Adj Close  253 non-null    float64
#  5   Volume     253 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.8 KB
# None

# %%
# when the index is Date, we can use that date as our row number in the index
# finding one specific year or year-month
data_date_time_index['2020-07']
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-07-01  10063.669922  10197.190430  10048.040039  10154.629883
# 2020-07-02  10268.669922  10310.360352  10194.059570  10207.629883
# 2020-07-06  10360.379883  10462.049805  10354.980469  10433.650391
# 2020-07-07  10412.459961  10518.980469  10337.980469  10343.889648
# 2020-07-08  10409.349609  10494.629883  10350.959961  10492.500000
# 2020-07-09  10563.719727  10578.099609  10379.910156  10547.750000
# 2020-07-10  10545.910156  10622.349609  10447.009766  10617.440430
# 2020-07-13  10729.919922  10824.780273  10368.040039  10390.839844
# 2020-07-14  10310.250000  10497.830078  10182.459961  10488.580078
# 2020-07-15  10576.719727  10604.669922  10420.540039  10550.490234
# 2020-07-16  10443.870117  10499.790039  10364.389648  10473.830078
# 2020-07-17  10500.519531  10532.620117  10421.209961  10503.190430
# 2020-07-20  10526.019531  10783.799805  10488.040039  10767.089844
# ...

# %%
# finding one specific day
data_date_time_index.loc['2020-07-29']
# Out:
# Open         1.047470e+04
# High         1.056791e+04
# Low          1.046400e+04
# Close        1.054294e+04
# Adj Close    1.054294e+04
# Volume       3.970900e+09
# Name: 2020-07-29 00:00:00, dtype: float64

# %%
# Create dataframe prices here
close_prices = pd.DataFrame()

# Use the iteration variable to select the data for this year and the column price.
# Select data for each year and concatenate with prices here 
for year in ['2020', '2021']:
    price_per_year = data_date_time_index.loc[year, ['Close']].reset_index(drop=True) # Use .reset_index() with drop=True to remove the DatetimeIndex
    price_per_year.rename(columns={'Close': year}, inplace=True) # Rename the column price column to the appropriate year
    close_prices = pd.concat([close_prices, price_per_year], axis=1) # Use pd.concat() to combine the yearly data with the data in prices along axis=1.

# Plot prices
close_prices.plot()
plt.show()

# %%
close_prices.head()
# Out:
#            2020          2021
# 0   9895.870117  12698.450195
# 1   9910.530273  12818.959961
# 2   9943.049805  12740.790039
# 3   9946.120117  13067.480469
# 4  10056.480469  13201.980469

# %%
# see how changing frequency works
# you have seen how to assign a frequency to a DateTimeIndex, and then change this frequency.
# Inspect data
print(data_date_time_index.info())

# Set the frequency to calendar daily
data_date_time_index_daily_freq = data_date_time_index.asfreq('D')

# Plot the data
data_date_time_index_daily_freq.plot(subplots=True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 253 entries, 2020-06-16 to 2021-06-16
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       253 non-null    float64
#  1   High       253 non-null    float64
#  2   Low        253 non-null    float64
#  3   Close      253 non-null    float64
#  4   Adj Close  253 non-null    float64
#  5   Volume     253 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 23.8 KB
# None

# %%
data_date_time_index_daily_freq.head()
# Out:
#                     Open          High          Low        Close    Adj Close  \
# Date
# 2020-06-16   9949.780273   9963.629883  9748.379883  9895.870117  9895.870117
# 2020-06-17   9943.309570   9991.209961  9891.809570  9910.530273  9910.530273
# 2020-06-18   9892.480469   9959.200195  9885.660156  9943.049805  9943.049805
# 2020-06-19  10042.129883  10053.910156  9872.940430  9946.120117  9946.120117
# 2020-06-20           NaN           NaN          NaN          NaN          NaN
#
#                   Volume
# Date
# 2020-06-16  4.639860e+09
# 2020-06-17  4.249680e+09
# 2020-06-18  4.294740e+09
# 2020-06-19  6.068130e+09
# 2020-06-20           NaN

# %%
# Set frequency to monthly
data_date_time_index_monthly_freq = data_date_time_index_daily_freq.asfreq('M')

# Plot the data
data_date_time_index_monthly_freq.plot(subplots=True)
plt.show()

# %%
data_date_time_index_monthly_freq
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-06-30   9875.290039  10085.589844   9863.669922  10058.769531
# 2020-07-31  10741.469727  10747.799805  10557.700195  10745.269531
# 2020-08-31  11718.809570  11829.839844  11697.419922  11775.459961
# 2020-09-30  11092.900391  11277.959961  11092.900391  11167.509766
# 2020-10-31           NaN           NaN           NaN           NaN
# 2020-11-30  12224.250000  12244.650391  12027.160156  12198.740234
# 2020-12-31  12877.089844  12902.070313  12821.230469  12888.280273
# 2021-01-31           NaN           NaN           NaN           NaN
# 2021-02-28           NaN           NaN           NaN           NaN
# 2021-03-31  13122.570313  13325.540039  13118.379883  13246.870117
# 2021-04-30  13970.730469  14084.759766  13941.629883  13962.679688
# 2021-05-31           NaN           NaN           NaN           NaN
#
#                Adj Close        Volume
# Date
# 2020-06-30  10058.769531  4.474000e+09
# ...

# %%
# instead of using to_datetime function to change date from object or string to datetime we can do it when we 
# are downloading the date using read_csv by adding pase_date = ["name of date column"] (as a list), we can also use
# the set_index as well by index_col = 'name of the date column'

my_data = pd.read_excel("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\sample data for timeseris.xlsx", 
                    parse_dates=['Date'], index_col='Date')
my_data.head()
# Out:
#             Price
# Date
# 2020-01-01    118
# 2020-01-02    167
# 2020-01-03    182
# 2020-01-04    130
# 2020-01-05    151

# %%
# shifting data is useful to compare date at different point in times
# using shift function we can shift data by number of periods we specify
my_data['shifted'] = my_data.Price.shift(periods = +1) # the first two data will be missing
my_data
# Out:
#             Price  shifted
# Date
# 2020-01-01    118      NaN
# 2020-01-02    167    118.0
# 2020-01-03    182    167.0
# 2020-01-04    130    182.0
# 2020-01-05    151    130.0
# 2020-01-06    139    151.0
# 2020-01-07    120    139.0
# 2020-01-08    198    120.0
# 2020-01-09    161    198.0
# 2020-01-10    147    161.0
# 2020-01-11    110    147.0
# 2020-01-12    130    110.0
# 2020-01-13    195    130.0
# 2020-01-14    199    195.0
# 2020-01-15    200    199.0
# 2020-01-16    189    200.0
# 2020-01-17    143    189.0
# 2020-01-18    172    143.0
# 2020-01-19    132    172.0
# 2020-01-20    101    132.0
# 2020-01-21    131    101.0
# 2020-01-22    192    131.0
# 2020-01-23    144    192.0
# 2020-01-24    160    144.0
# 2020-01-25    100    160.0
# 2020-01-26    171    100.0
# 2020-01-27    165    171.0
# 2020-01-28    146    165.0
# 2020-01-29    183    146.0
# 2020-01-30    183    183.0
# 2020-01-31    160    183.0
# 2020-02-01    181    160.0
# 2020-02-02    118    181.0
# ...

# %%
# by using negative number we move date to the past
my_data['lagged'] = my_data.Price.shift(periods = -1)  # the last date will be miising
my_data
# Out:
#             Price  shifted  lagged
# Date
# 2020-01-01    118      NaN   167.0
# 2020-01-02    167    118.0   182.0
# 2020-01-03    182    167.0   130.0
# 2020-01-04    130    182.0   151.0
# 2020-01-05    151    130.0   139.0
# 2020-01-06    139    151.0   120.0
# 2020-01-07    120    139.0   198.0
# 2020-01-08    198    120.0   161.0
# 2020-01-09    161    198.0   147.0
# 2020-01-10    147    161.0   110.0
# 2020-01-11    110    147.0   130.0
# 2020-01-12    130    110.0   195.0
# 2020-01-13    195    130.0   199.0
# 2020-01-14    199    195.0   200.0
# 2020-01-15    200    199.0   189.0
# 2020-01-16    189    200.0   143.0
# 2020-01-17    143    189.0   172.0
# 2020-01-18    172    143.0   132.0
# 2020-01-19    132    172.0   101.0
# 2020-01-20    101    132.0   131.0
# 2020-01-21    131    101.0   192.0
# 2020-01-22    192    131.0   144.0
# 2020-01-23    144    192.0   160.0
# 2020-01-24    160    144.0   100.0
# 2020-01-25    100    160.0   171.0
# ...

# %%
# as mentioned shifting data is useful to compare date at different point in times, for example calulting dollar and % growt
my_data['dollar_change'] = my_data['Price'] - my_data['shifted']
my_data['return'] = round(my_data['dollar_change'] / my_data['shifted'], 2)
my_data.head()
# Out:
#             Price  shifted  lagged  dollar_change  return
# Date
# 2020-01-01    118      NaN   167.0            NaN     NaN
# 2020-01-02    167    118.0   182.0           49.0    0.42
# 2020-01-03    182    167.0   130.0           15.0    0.09
# 2020-01-04    130    182.0   151.0          -52.0   -0.29
# 2020-01-05    151    130.0   139.0           21.0    0.16

# %%
# we can claculate the differnce between data at different time using diff method which works vertically
my_data = pd.read_excel("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\sample data for timeseris.xlsx", 
                    parse_dates=['Date'], index_col='Date')

my_data['change'] = my_data.Price.diff(periods = 1)
my_data.head()
# Out:
#             Price  change
# Date
# 2020-01-01    118     NaN
# 2020-01-02    167    49.0
# 2020-01-03    182    15.0
# 2020-01-04    130   -52.0
# 2020-01-05    151    21.0

# %%
# we can also calculate percentage change (return) directly  # for example for monthly return we can use periods = 30
my_data['% change'] = my_data.Price.pct_change(periods = 1)
my_data.head()
# Out:
#             Price  change  % change
# Date
# 2020-01-01    118     NaN       NaN
# 2020-01-02    167    49.0  0.415254
# 2020-01-03    182    15.0  0.089820
# 2020-01-04    130   -52.0 -0.285714
# 2020-01-05    151    21.0  0.161538

# %%
# using shift yous can see seasonality and make comparisons between seasons
# Import data here
my_data = pd.read_csv("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\Nasdaq.csv", 
                    parse_dates=['Date'], index_col='Date')
# Set data frequency to business daily
my_data = my_data.asfreq('B')

# Create 'lagged' and 'shifted'
my_data['lagged'] = my_data.Close.shift(periods = -90)
my_data['shifted'] = my_data.Close.shift(periods = +90)

# Plot the google price series
my_data['Close'].plot()
my_data['shifted'].plot()
my_data['lagged'].plot()

plt.show()

# %%
# Set data frequency to business daily
my_data = my_data.asfreq('B')

# we can compare daily, monthly, and annual return
# Create daily_return
google['daily_return'] = google.Close.pct_change(1).mul(100)

# Create monthly_return
google['monthly_return'] = google.Close.pct_change(30).mul(100)

# Create annual_return
google['annual_return'] = google.Close.pct_change(360).mul(100)

# Plot the result
google[['daily_return' , 'monthly_return', 'annual_return']].plot(subplots=True)

plt.show()

# %%
# normalizing a simple time series to make it comparable to other time series
google = pd.read_csv("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\GOOG.csv", 
                    parse_dates=['Date'], index_col='Date')
# Set data frequency to business daily
my_data = my_data.asfreq('B')
google.head(3)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897

# %%
first_close_price = google['Close'].iloc[0]
first_close_price
# Out:
# 49.982655

# %%
# you could also use another way to get that, as Date is the index
first_close_price = google.loc['2004-08-19', 'Close']
first_close_price
# Out:
# 49.982655

# %%
# to normalize, we devide all close prices by the first price and multiple it by 100
google['normalized'] = google.Close.div(first_close_price).mul(100)
google[['Close', 'normalized']].tail()
# Out:
#                   Close   normalized
# Date
# 2021-06-14  2527.040039  5055.833947
# 2021-06-15  2520.659912  5043.069265
# 2021-06-16  2513.929932  5029.604634
# 2021-06-17  2527.419922  5056.593976
# 2021-06-18  2511.350098  5024.443175

# %%
# if you plot it you will see the price start with 100
google['normalized'].plot(title = 'google normalized series')
plt.show()

# %%
# when we want to compare different stocks, first we should put all on the same spreassheet
stock_prices = pd.read_excel("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\stocks of apple google amazon.xlsx", 
                    parse_dates=['Date'], index_col='Date')
# Set data frequency to business daily

stock_prices.head(3)
# Out:
#              apple   google   amazon
# Date
# 2019-01-31  41.610  1116.37  1718.73
# 2019-02-28  43.288  1119.92  1639.83
# 2019-03-29  47.488  1173.31  1780.75

# %%
# then we define a new DataFrame called normalized (devied each price by its corresponding first_price)
normalizaed = stock_prices.div(stock_prices.iloc[0]).mul(100) # you see we did it with only one line of code
normalizaed.head()
# Out:
#                  apple      google      amazon
# Date
# 2019-01-31  100.000000  100.000000  100.000000
# 2019-02-28  104.032684  100.317995   95.409401
# 2019-03-29  114.126412  105.100460  103.608478
# 2019-04-30  120.567171  106.459328  112.089741
# 2019-05-31  105.186253   98.858801  103.278002

# %%
normalizaed.plot(title = 'Normalized series')
plt.show()

# %%
# now we want to add another time series to the above as our benchmark derived from S&P 500
# lets download sp500
sp500_prices = pd.read_excel("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\sp500 index price.xlsx",
                             parse_dates=['Date'], index_col='Date')

sp500_prices.head(3)
# Out:
#               Close
# Date
# 2020-12-31  3756.07
# 2020-12-30  3732.04
# 2020-12-29  3727.04

# %%
# lets remove the columns we do not need
#sp500_prices.drop(['Open', 'High', 'Low'], inplace=True, axis = 1)
sp500_prices.head()
# Out:
#               Close
# Date
# 2020-12-31  3756.07
# 2020-12-30  3732.04
# 2020-12-29  3727.04
# 2020-12-28  3735.36
# 2020-12-24  3703.06

# %%
# now we want to copmare, but our google, amazon, apple data are monthly, sp500 is daily, lets change it to monthly
sp500_prices_monthly = sp500_prices.resample('M').last() # we can use mean instead of last to use the average monthly
sp500_prices_monthly.head()
# Out:
#               Close
# Date
# 2019-01-31  2704.10
# 2019-02-28  2784.49
# 2019-03-31  2834.40
# 2019-04-30  2945.83
# 2019-05-31  2752.06

# %%
# as you see by making it to monthly we have the same number of rows for both sp500 and normalized data fram of 3 companies
sp500_prices_monthly.count()
# Out:
# Close    24
# dtype: int64

# %%
normalizaed.apple.count()
# Out:
# 24

# %%
# then we add normalize our sp500 as well
normalizaed_sp500 = sp500_prices_monthly.div(sp500_prices_monthly.iloc[0]).mul(100) # you see we did it with only one line of code
normalizaed_sp500.head()
# Out:
#                  Close
# Date
# 2019-01-31  100.000000
# 2019-02-28  102.972893
# 2019-03-31  104.818609
# 2019-04-30  108.939388
# 2019-05-31  101.773603

# %%
# then we add this to our initial normalized datafarme
normalizaed_all = pd.concat([normalizaed, normalizaed_sp500], axis = 1).dropna() # since they are coming from different data sources make 
# sure to use dropna() to drop none values
normalizaed_all.head()
# Out:
#                  apple      google      amazon       Close
# Date
# 2019-01-31  100.000000  100.000000  100.000000  100.000000
# 2019-02-28  104.032684  100.317995   95.409401  102.972893
# 2019-04-30  120.567171  106.459328  112.089741  108.939388
# 2019-05-31  105.186253   98.858801  103.278002  101.773603
# 2019-07-31  127.998077  108.985372  108.613918  110.217078

# %%
# change the name of column Close to sp500
normalizaed_all['sp500'] = normalizaed_all['Close']
normalizaed_all.head()
# Out:
#                  apple      google      amazon       Close       sp500
# Date
# 2019-01-31  100.000000  100.000000  100.000000  100.000000  100.000000
# 2019-02-28  104.032684  100.317995   95.409401  102.972893  102.972893
# 2019-04-30  120.567171  106.459328  112.089741  108.939388  108.939388
# 2019-05-31  105.186253   98.858801  103.278002  101.773603  101.773603
# 2019-07-31  127.998077  108.985372  108.613918  110.217078  110.217078

# %%
normalizaed_all.drop(['Close'], axis = 1, inplace = True)
normalizaed_all.head()
# Out:
#                  apple      google      amazon       sp500
# Date
# 2019-01-31  100.000000  100.000000  100.000000  100.000000
# 2019-02-28  104.032684  100.317995   95.409401  102.972893
# 2019-04-30  120.567171  106.459328  112.089741  108.939388
# 2019-05-31  105.186253   98.858801  103.278002  101.773603
# 2019-07-31  127.998077  108.985372  108.613918  110.217078

# %%
normalizaed_all.plot(title = 'Normalized series')
plt.show()

# %%
# to show the performance difference for each stock relative to sp500, 
# first we set three stocks in a list called tickers
tickers = ['apple', 'google', 'amazon']
diff = normalizaed_all[tickers].sub(normalizaed_all['sp500'], axis = 0)
diff.plot()
# 0 is our benchmark(sp500), anything below that is underperforming and above zero is outperfoming sp500
plt.show()

# %%
# seeing how upsampling and downsamling using asfreq work:
# first lets creat a simple dateindex dataframe
dates = pd.date_range(start='2016', periods=4, freq='Q')
data = range(1, 5)
quarterly = pd.Series(data=data, index=dates) # be careful we created as series using two different ranges, this series is 
quarterly = quarterly.to_frame('baseline')    # not a DataFrame, to convert it to datafarme we should use to_frame
quarterly.head()
# Out:
#             baseline
# 2016-03-31         1
# 2016-06-30         2
# 2016-09-30         3
# 2016-12-31         4

# %%
# lets change the frequency and see what heppens
monthly = quarterly.asfreq('M') # it adds new month-end date between the existing dates, but there are missing values
monthly
# Out:
#             baseline
# 2016-03-31       1.0
# 2016-04-30       NaN
# 2016-05-31       NaN
# 2016-06-30       2.0
# 2016-07-31       NaN
# 2016-08-31       NaN
# 2016-09-30       3.0
# 2016-10-31       NaN
# 2016-11-30       NaN
# 2016-12-31       4.0

# %%
# there are three ways that panadas offers to fill these missing values, there is interpolate method we will explain later.
# method one: forward fill
monthly = quarterly.asfreq('M', method = 'ffill' ) 
monthly
# Out:
#             baseline
# 2016-03-31         1
# 2016-04-30         1
# 2016-05-31         1
# 2016-06-30         2
# 2016-07-31         2
# 2016-08-31         2
# 2016-09-30         3
# 2016-10-31         3
# 2016-11-30         3
# 2016-12-31         4

# %%
# method two: backward fill
monthly = quarterly.asfreq('M', method = 'bfill' ) 
monthly
# Out:
#             baseline
# 2016-03-31         1
# 2016-04-30         2
# 2016-05-31         2
# 2016-06-30         2
# 2016-07-31         3
# 2016-08-31         3
# 2016-09-30         3
# 2016-10-31         4
# 2016-11-30         4
# 2016-12-31         4

# %%
# method 3: provideing value to fill ourselves
monthly = quarterly.asfreq('M', fill_value = 777 ) 
monthly
# Out:
#             baseline
# 2016-03-31         1
# 2016-04-30       777
# 2016-05-31       777
# 2016-06-30         2
# 2016-07-31       777
# 2016-08-31       777
# 2016-09-30         3
# 2016-10-31       777
# 2016-11-30       777
# 2016-12-31         4

# %%
# if we have a range of date which is more frequent that the dataframe, and want to use them as index, we use reindex
# we need to know how to use .reindex() to conform an existing time series to a DateTimeIndex at a different frequency.
monthly_date_range = pd.date_range(start = '2016', periods = 12, freq = 'M')
monthly_date_range
# Out:
# DatetimeIndex(['2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30',
#                '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31',
#                '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
quarterly
# Out:
#             baseline
# 2016-03-31         1
# 2016-06-30         2
# 2016-09-30         3
# 2016-12-31         4

# %%
quarterly_montly_date = quarterly.reindex(monthly_date_range)
quarterly_montly_date
# Out:
#             baseline
# 2016-01-31       NaN
# 2016-02-29       NaN
# 2016-03-31       1.0
# 2016-04-30       NaN
# 2016-05-31       NaN
# 2016-06-30       2.0
# 2016-07-31       NaN
# 2016-08-31       NaN
# 2016-09-30       3.0
# 2016-10-31       NaN
# 2016-11-30       NaN
# 2016-12-31       4.0

# %%
# here we can also use the three method mentioned above: ffill, bfill, fill_value = ???
quarterly_montly_date = quarterly.reindex(monthly_date_range, method = 'ffill')
quarterly_montly_date
# Out:
#             baseline
# 2016-01-31       NaN
# 2016-02-29       NaN
# 2016-03-31       1.0
# 2016-04-30       1.0
# 2016-05-31       1.0
# 2016-06-30       2.0
# 2016-07-31       2.0
# 2016-08-31       2.0
# 2016-09-30       3.0
# 2016-10-31       3.0
# 2016-11-30       3.0
# 2016-12-31       4.0

# %%
# lets do the above procedure one more time again with different data
# Set start and end dates
start = '2016-1-1'
end = '2016-2-29'

# Create monthly_dates here
monthly_dates = pd.date_range(start = start, end = end, freq = 'M')

# Create and print monthly here
monthly = pd.Series(data = [1, 2], index = monthly_dates)
print(monthly)

# Create weekly_dates here
weekly_dates = pd.date_range(start = start, end = end, freq = 'W')

# Print monthly, reindexed using weekly_dates
print(monthly.reindex(weekly_dates))
print(monthly.reindex(weekly_dates, method = 'bfill'))
print(monthly.reindex(weekly_dates, method = 'ffill'))
# Out:
# 2016-01-31    1
# 2016-02-29    2
# Freq: M, dtype: int64
# 2016-01-03    NaN
# 2016-01-10    NaN
# 2016-01-17    NaN
# 2016-01-24    NaN
# 2016-01-31    1.0
# 2016-02-07    NaN
# 2016-02-14    NaN
# 2016-02-21    NaN
# 2016-02-28    NaN
# Freq: W-SUN, dtype: float64
# 2016-01-03    1
# 2016-01-10    1
# 2016-01-17    1
# 2016-01-24    1
# 2016-01-31    1
# 2016-02-07    2
# 2016-02-14    2
# 2016-02-21    2
# 2016-02-28    2
# Freq: W-SUN, dtype: int64
# 2016-01-03    NaN
# 2016-01-10    NaN
# 2016-01-17    NaN
# 2016-01-24    NaN
# 2016-01-31    1.0
# 2016-02-07    1.0
# 2016-02-14    1.0
# 2016-02-21    1.0
# 2016-02-28    1.0
# Freq: W-SUN, dtype: float64

# %%
# resample method is similar to group by method which aggregated data when downsampling ,
# and fill or interpolate when upsampling

unrate = pd.read_excel("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\unemployment-rate.xlsx",
                             parse_dates=['Date'], index_col='Date')
unrate.head()
# Out:
#             UNRATE
# Date
# 2021-03-31    8.37
# 2020-12-31    8.80
# 2020-09-30   10.10
# 2020-06-30   13.10
# 2020-03-31    6.40

# %%
# basically datetime index sort index by date, but here it did not happen, so i used the below command to sort based on date.
unrate.sort_index(inplace = True, ascending= True)
unrate.head()
# Out:
#             UNRATE
# Date
# 2001-06-29    7.10
# 2001-09-28    7.17
# 2001-12-31    7.63
# 2002-03-29    7.93
# 2002-06-28    7.70

# %%
# we can different things for asfreq : Calender Month End: M, Calender Month Start: MS 
                                     # Business Month End: BM, Business Month Start: BMS   
unrate.asfreq('BM').head()
# Out:
#             UNRATE
# Date
# 2001-06-29    7.10
# 2001-07-31     NaN
# 2001-08-31     NaN
# 2001-09-28    7.17
# 2001-10-31     NaN

# %%
# my opinion: resample is an easier way than asfreq
# upsamling: creates a lot of NaN values, so we can use ffill or bfill or ... to fill them
unrate.resample('W').ffill().add_suffix('_ffill') # add_suffix adds more words to the existing one.
# Out:
#             UNRATE_ffill
# Date
# 2001-07-01          7.10
# 2001-07-08          7.10
# 2001-07-15          7.10
# 2001-07-22          7.10
# 2001-07-29          7.10
# ...                  ...
# 2021-03-07          8.80
# 2021-03-14          8.80
# 2021-03-21          8.80
# 2021-03-28          8.80
# 2021-04-04          8.37
#
# [1032 rows x 1 columns]

# %%
# another great way to fill missing values is to use interpolate
unrate.resample('D').interpolate().add_suffix('_inter').head()
# Out:
#             UNRATE_inter
# Date
# 2001-06-29      7.100000
# 2001-06-30      7.100769
# 2001-07-01      7.101538
# 2001-07-02      7.102308
# 2001-07-03      7.103077

# %%
# when downsampling, we need to aggregate
# Import and inspect data here
stocks = pd.read_excel("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\stocks of apple google amazon.xlsx", 
                    parse_dates=['Date'], index_col='Date')
print(stocks.info())

# Calculate and plot the Quarterly averages (monthly to quarterly)
monthly_average = stocks.resample('Q').mean()
monthly_average.plot(subplots = True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 24 entries, 2019-01-31 to 2020-12-31
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   apple   24 non-null     float64
#  1   google  24 non-null     float64
#  2   amazon  24 non-null     float64
# dtypes: float64(3)
# memory usage: 768.0 bytes
# None

# %%
# you can aggregate in different forms at the same time using agg
# Import data here
sp500 = pd.read_excel("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\sp500 index price.xlsx",
                             parse_dates=['Date'], index_col='Date')

print(sp500.info())

# Calculate daily returns here
daily_returns = sp500.squeeze().pct_change()

# Resample and calculate statistics
stats = daily_returns.resample('M').agg(['mean', 'median', 'std'])

# Plot stats here
stats.plot()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 485 entries, 2020-12-31 to 2019-01-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   485 non-null    float64
# dtypes: float64(1)
# memory usage: 7.6 KB
# None

# %%
# Window Functions: Rolling & Expanding Metrics
# Window functions are useful because they allow you to operate on sub periods of your time series. 
# In particular, window functions calculate metrics for the data inside the window. Then, the result of this
# calculation forms a new time series, where each data point represents a summary of several data points of 
# the original time series. A big example is : for example 30 days moving average
# Rolling windows maintain the same size while they slide over the time series, so each new data point
# is the result of a given number of observations. Expanding windows grow with the time series, 
# so that the calculation that produces a new data point is the result of all previous data points
sp500 = pd.read_excel("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\sp500 index price.xlsx",
                             parse_dates=['Date'], index_col='Date').dropna()

sp500.head(4)
# Out:
#               Close
# Date
# 2020-12-31  3756.07
# 2020-12-30  3732.04
# 2020-12-29  3727.04
# 2020-12-28  3735.36

# %%
# when volatility is high, using moving average helps undertand the trend more clearly.
# lets calculate the moving average
sp500.rolling(window = 3).mean().head(3) # becareful, this result is not correct since it did not sort base on the date
# Out:
#                   Close
# Date
# 2020-12-31          NaN
# 2020-12-30          NaN
# 2020-12-29  3738.383333

# %%
# basically datetime index sort index by date, but here it did not happen, so i used the below command to sort based on date.
sp500.sort_index(inplace = True, ascending= True)
sp500.head(4)
# Out:
#               Close
# Date
# 2019-01-31  2704.10
# 2019-02-01  2706.53
# 2019-02-04  2724.87
# 2019-02-05  2737.70

# %%
sp500.rolling(window = 3).mean().head(4)   # this is an example of rolling window with 3 data points returning mean
# window = 3 is alos equvalnet to 3 business days, because we have one observation in each business day.
# Out:
#                   Close
# Date
# 2019-01-31          NaN
# 2019-02-01          NaN
# 2019-02-04  2711.833333
# 2019-02-05  2723.033333

# %%
# instead of observations, you can choose number of days for example 30D is the number of calender days
# this remove NaN values
sp500.rolling(window = "3D").mean().head(4)
# Out:
#                Close
# Date
# 2019-01-31  2704.100
# 2019-02-01  2705.315
# 2019-02-04  2724.870
# 2019-02-05  2731.285

# %%
# you can add this new window to your original data using join which works loke concat
sp500_30days_moving_average = sp500.rolling(window = "30D").mean()
sp500_oringinal_and_moving_average = sp500.join(sp500_30days_moving_average.add_suffix('30_mean'))
sp500_oringinal_and_moving_average.head()
# Out:
#               Close  Close30_mean
# Date
# 2019-01-31  2704.10   2704.100000
# 2019-02-01  2706.53   2705.315000
# 2019-02-04  2724.87   2711.833333
# 2019-02-05  2737.70   2718.300000
# 2019-02-06  2731.61   2720.962000

# %%
sp500_oringinal_and_moving_average.plot() # you can see that moving average is smoother becasue it absorb the volatility
# 30 days

# %%
# the wider the time hirizon the smother the plot would be
sp500_oringinal_and_moving_average.join(sp500.rolling(window = '90D').mean().add_suffix('90_mean')).plot()

# %%
# similar to the prevoius we can calculate different statistics at the same time
sp500_30days_moving_average_and_std = sp500.rolling(window = "30D").agg(['mean', 'std'])
sp500_30days_moving_average_and_std.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED4D7E94C8>,
# ...
#       dtype=object)

# %%
# one of the useful application of rolling window is in determinig quantiles
# instead of mean you can use quantiles
sp500_rolled = sp500.rolling(window = "30D")

sp500_rolledl_q10 = sp500_rolled.quantile(0.1)
sp500_rolledl_median = sp500_rolled.median()
sp500_rolledl_q90 = sp500_rolled.quantile(0.9)

pd.concat([sp500_rolledl_q10, sp500_rolledl_median, sp500_rolledl_q90], axis =1).plot()
# where the distance between line is wider it shows more volatility

# %%
# if your original data has multiple columns, do not forget to define the column that has to be rolled
stock_prices = pd.read_excel("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\stocks of apple google amazon.xlsx", 
                    parse_dates=['Date'], index_col='Date').dropna() # use dropna to avoid error
stock_prices.head(3)
# Out:
#              apple   google   amazon
# Date
# 2019-01-31  41.610  1116.37  1718.73
# 2019-02-28  43.288  1119.92  1639.83
# 2019-03-29  47.488  1173.31  1780.75

# %%
stock_prices['apple_day90_mean'] = stock_prices.apple.rolling(window = "90D").mean()
stock_prices['apple_day120_mean'] = stock_prices.apple.rolling(window = "120D").mean()
stock_prices.head()
# Out:
#              apple   google   amazon  apple_day90_mean  apple_day120_mean
# Date
# 2019-01-31  41.610  1116.37  1718.73         41.610000          41.610000
# 2019-02-28  43.288  1119.92  1639.83         42.449000          42.449000
# 2019-03-29  47.488  1173.31  1780.75         44.128667          44.128667
# 2019-04-30  50.168  1188.48  1926.52         45.638500          45.638500
# 2019-05-31  43.768  1103.63  1775.07         47.141333          46.178000

# %%
stock_prices[['apple', 'apple_day90_mean', 'apple_day120_mean']].plot()

# %%
# if we want to plot a specific period of time, not the whole time period in our data:
stock_prices.loc['2019-04':'2020-9' , ['apple', 'apple_day90_mean', 'apple_day120_mean']].plot()

# %%
# as mentioned, there is another window function: expanding windows: usful for accumulated rate of return, and
# running maximum or minimum.
# running rate of return : cumulative return
sp500 = pd.read_excel("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\sp500 index price.xlsx",
                             parse_dates=['Date'], index_col='Date').dropna()

sp500.sort_index(inplace = True, ascending= True)
sp500['return'] = sp500.pct_change()
sp500['cum-return'] = (1 + sp500['return']).cumprod().sub(1)
sp500.head()
# Out:
#               Close    return  cum-return
# Date
# 2019-01-31  2704.10       NaN         NaN
# 2019-02-01  2706.53  0.000899    0.000899
# 2019-02-04  2724.87  0.006776    0.007681
# 2019-02-05  2737.70  0.004708    0.012426
# 2019-02-06  2731.61 -0.002224    0.010173

# %%
sp500[['return', 'cum-return']].plot()

# %%
# using expanding method for running min and running max
sp500['running_min'] = sp500.Close.expanding().min()
sp500['running_max'] = sp500.Close.expanding().max()
sp500[['Close', 'running_max', 'running_min']].plot()

# %%
# if we have a portfolio fo different stocks, we can plot their retrurn all in one praph

data = pd.read_excel("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\stocks of apple google amazon.xlsx", 
                    parse_dates=['Date'], index_col='Date')
investment = 100

# Calculate the daily returns here
returns = data.pct_change()

# Calculate the cumulative returns here
returns_plus_one = returns.add(1)
cumulative_return = returns_plus_one.cumprod()

# Calculate and plot the investment return here 
cumulative_return.mul(investment).plot()
plt.show()

# %%
# Define a multi_period_return function
def multi_period_return(period_returns):
    return np.prod(period_returns + 1)-1
    
# Calculate daily returns
daily_returns = data.pct_change()

# Calculate rolling_annual_returns
rolling_annual_returns = daily_returns.rolling('360D').apply(multi_period_return)

# Plot rolling_annual_returns
rolling_annual_returns.mul(100).plot()
plt.show()

# %%
# random walk and simulation
# perdicting prices using returns

data = pd.read_excel("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\sp500daily_from 2016.xlsx", 
                    parse_dates=['Date'], index_col='Date')
data['returns'] = data.pct_change()
data.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED4D4C5308>,
# ...
#       dtype=object)

# %%
# Daily stock returns are hard to predict
# Models often assume they are random in nature
# Numpy allows you to generate random numbers
# From random returns to prices: use .cumprod()

# %%
# to genrate random numbers and compare them to normal distribution, import the following packages
from numpy.random import normal, seed
from scipy.stats import norm
import seaborn as sns

# you can set the seed to generate the same random numbers every time you run the codes
seed(42)
# lets genrerate 1000 random returns
random_returns = normal(loc = 0, scale = 0.01 , size = 1000) # generate 1000 random numbers with mean of zero (loc=0)
# by changing scale you see the difference. the higher scacle, the lower the frequiency number the wider x axis
# as you see from the above chart, the daily return is has always been sth betewwn +-0.03
sns.distplot(random_returns, fit = norm, kde = False)

# %%
# create a random price path from the above random return
#convert random returns to series
random_returns_series = pd.Series(random_returns)

random_prices = random_returns_series.add(1).cumprod()
random_prices.mul(100).plot(subplots = True)
plt.show()

# %%
sns.distplot(random_prices, fit = norm, kde = False)

# %%
# Random Walk: randomly select bumbers from existing historin numbers instead of using a specific distribution
# please note that in the above simulation when we assumed that returns have normal distribution, But it is not always 
# the case, and maybe the actual historic returns have a different or even unknown distribution. in this cases it is 
# better to select returns from historic returns and use them instead of rendomly generate numbers with specific distributn

# lets see the actual distribution of historic returns of SP500
data['returns'] = data.pct_change()
sns.distplot(data['returns'], fit = norm, kde = False)
# as you see the actual distribution is not normal. So we should generate numbers using this unknown distribution

# %%
# To do so import relevant package
from numpy.random import choice

# get sample
sample = data.returns.dropna()

# get number of observations
no_obs = data.returns.count()

# Use random walk
random_walk = choice(sample, size = no_obs) # choice() is an inbuilt function in Python that returns
                                            # a random item from a list, tuple, or string
# convert random walk to series
random_walk = pd.Series(random_walk, index= sample.index)

# %%
# now start from the first price and generate prices with these new genrated returns using random walk

# get the first price
first_price = data.Price.first('D')
sp500_random = first_price.append(random_walk.add(1))

# lets calculate the cumulative return
data['sp500_random'] = sp500_random.cumprod().sub(1)
data[['Price', 'sp500_random']].plot()

# %%
# correlation and linear relationship between variables
# lets download a data including: sp500, 10yeat Tbill, oil, gold, amazon
data = pd.read_excel("F:\\schulich\\datacamp\\python finance fundamentals\\data used for python\\sp500-nasdaq-oil-gold-10yearTbill.xlsx", 
                    parse_dates=['Date'], index_col='Date').dropna()
data.head()
# Out:
#                oil     gold   tbill    sp500   nasdaq
# Date
# 2016-06-03  270.00  1244.20  1.7004  2099.13  4942.52
# 2016-06-06  273.90  1245.34  1.7367  2109.41  4968.71
# 2016-06-07  281.14  1243.81  1.7177  2112.13  4961.75
# 2016-06-08  281.95  1262.80  1.7022  2119.12  4974.64
# 2016-06-09  279.13  1269.80  1.6867  2115.48  4958.62

# %%
daily_returns = data.pct_change()
daily_returns.head()
# Out:
#                  oil      gold     tbill     sp500    nasdaq
# Date
# 2016-06-03       NaN       NaN       NaN       NaN       NaN
# 2016-06-06  0.014444  0.000916  0.021348  0.004897  0.005299
# 2016-06-07  0.026433 -0.001229 -0.010940  0.001289 -0.001401
# 2016-06-08  0.002881  0.015268 -0.009024  0.003309  0.002598
# 2016-06-09 -0.010002  0.005543 -0.009106 -0.001718 -0.003220

# %%
# visualize pairwise linear relationship
sns.pairplot(daily_returns)

# %%
# if you want to plot some specific pairs:
sns.jointplot(x = 'nasdaq', y = 'gold', data = daily_returns)

# %%
# calculate all paitwise correlation coefficient
corr_coeff = daily_returns.corr()
corr_coeff
# Out:
#              oil      gold     tbill     sp500    nasdaq
# oil     1.000000 -0.015466  0.338321  0.507614  0.397584
# gold   -0.015466  1.000000 -0.278568  0.036152  0.058441
# tbill   0.338321 -0.278568  1.000000  0.479570  0.391354
# sp500   0.507614  0.036152  0.479570  1.000000  0.944659
# nasdaq  0.397584  0.058441  0.391354  0.944659  1.000000

# %%
# we can make this table much more visulaized
sns.heatmap(corr_coeff, annot = True, cmap = 'RdYlGn')
